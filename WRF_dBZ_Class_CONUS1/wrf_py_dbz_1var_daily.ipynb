# %% [markdown]
# ## Retrieve 3D Reflectivity from WRF Simulations using WRF-Python.
#
# **For [High Resolution WRF Simulations of the Current and Future Climate of North America](https://rda.ucar.edu/datasets/ds612.0/).**
#
# **Save one variable (dBZ) to daily files only for storage.**
#
# **Hungjui Yu 20210909**

# %%
import sys
import time
import datetime as dt
import pytz
from netCDF4 import Dataset
import numpy as np
import xarray as xr
import pandas as pd
import wrf
from wrf import (getvar, dbz, extract_times, destagger)
# import metpy
# import metpy.calc as mpcalc
# import metpy.units as units
# print(metpy.__version__)

# import dask

# %% [markdown]
# **Set input files paths and names:**

# %%
def set_input_names(file_date):

    file_path_1 = '/gpfs/fs1/collections/rda/data/ds612.0'
    file_path_2 = '/' + wrf_sim_type # '/CTRL3D'
    file_path_3 = '/{}'.format(file_date.strftime('%Y'))

    file_names = dict( P = file_path_1 + file_path_2 + file_path_3 + '/wrf3d_d01_CTRL_P_{}.nc'.format(file_date.strftime('%Y%m%d')) \
                     , TK = file_path_1 + file_path_2 + file_path_3 + '/wrf3d_d01_CTRL_TK_{}.nc'.format(file_date.strftime('%Y%m%d')) \
                     , QVAPOR = file_path_1 + file_path_2 + file_path_3 + '/wrf3d_d01_CTRL_QVAPOR_{}.nc'.format(file_date.strftime('%Y%m%d')) \
                     , QRAIN = file_path_1 + file_path_2 + file_path_3 + '/wrf3d_d01_CTRL_QRAIN_{}.nc'.format(file_date.strftime('%Y%m')) \
                     , QSNOW = file_path_1 + file_path_2 + file_path_3 + '/wrf3d_d01_CTRL_QSNOW_{}.nc'.format(file_date.strftime('%Y%m%d')) \
                     , QGRAUP = file_path_1 + file_path_2 + file_path_3 + '/wrf3d_d01_CTRL_QGRAUP_{}.nc'.format(file_date.strftime('%Y%m')) \
                     , Z = file_path_1 + file_path_2 + file_path_3 + '/wrf3d_d01_CTRL_Z_{}.nc'.format(file_date.strftime('%Y%m%d')) \
                     )
    
    return file_names

# file_name_list = set_file_paths_names(file_date_time)
# print(file_name_list)

# %% [markdown]
# **Get wrf output variables:**

# %%
def get_wrf_vars(file_name, var_name, time_index):

    wrf_file = Dataset(file_name)
    # wrf_var = getvar(wrf_file, wrf_var_to_read, timeidx=time_index_1) # This doesn't work for CONUS run files.
    wrf_var = getvar(wrf_file, var_name, timeidx=time_index, meta=False)
    # wrf_var_time = wrf.extract_times(wrf_file, timeidx=time_index)
    # print(wrf_var_time)
    
    return wrf_var

# %% [markdown]
# **Calculation for dBZ:**

# %%
def calculate_wrf_dbz(wrf_pres, wrf_temp, wrf_qv, wrf_qr, wrf_qs, wrf_qg):
    
    wrf_dbz = dbz(wrf_pres \
                , wrf_temp \
                , wrf_qv \
                , wrf_qr \
                , wrf_qs \
                , wrf_qg \
                # , use_varint=True \
                , use_liqskin=False \
                , meta=True \
                 )
    
    return wrf_dbz

# %% [markdown]
# **Set output file path and name:**

# %%
def set_output_name(output_file_datetime):

    # output_path = '/glade/u/home/hungjui/2scratch/DATA_WRF_CONUS_1_dBZ_v1.0'
    
    output_time = pd.to_datetime(output_file_datetime).strftime('%Y%m%d') # If input time type is numpy.datetime64:
    
    # output_name = output_path + '/wrf3d_d01_dbz_{}.nc'.format(file_date_time.strftime('%Y%m%d%H'))
    # output_name = output_path + '/wrf3d_d01_dbz_{}.nc'.format(output_time)
    output_name = '/wrf3d_d01_dbz_{}.nc'.format(output_time)

    return output_name

# %% [markdown]
# ### Main Function:

# %%
def main_function(file_date_time):
    
    ## Set file datetime:
    # file_date_time = dt.datetime(2013, 9, 13, 0, 0, 0, tzinfo=pytz.utc)
    print('Processing: {}'.format(file_date_time.strftime('%Y%m%d')), end=' ')
    
    ## Set input files paths and names:
    file_name_dict = set_input_names(file_date_time)

    ## Get the 3-hourly time list from P and QRAIN files:
    wrf_3hour_list_1 = wrf.extract_times(Dataset(file_name_dict['P']), timeidx=wrf.ALL_TIMES, meta=False, do_xtime=False)
    wrf_3hour_list_2 = wrf.extract_times(Dataset(file_name_dict['QRAIN']), timeidx=wrf.ALL_TIMES, meta=False, do_xtime=False)

    ## Set wrf variable list for reflectivity retrieval:
    wrf_vars_list = ['P', 'TK', 'QVAPOR', 'QRAIN', 'QSNOW', 'QGRAUP']

    ## Set dBZ data array and append calculated data:
    # wrf_dbz = xr.zeros_like(wrf_dataset_out['P'])
    
    for hi in range(len(wrf_3hour_list_1)):
        
        print(str(hi) + '| ', end=' ')

        ## Get the index for common time in different files (every 3-hour):
        common_index_2 = np.intersect1d(wrf_3hour_list_1[hi], wrf_3hour_list_2, return_indices=True)[2][0]

        ## Get wrf output variables:
        wrf_vars = {}
        for vname in wrf_vars_list:

            file_name = file_name_dict[vname]

            if ( vname in ['QRAIN', 'QGRAUP'] ):
                wrf_vars['{}'.format(vname)] = get_wrf_vars(file_name, vname, common_index_2)
                # wrf_vars['{}'.format(vname)] = xr.open_dataset(file_name)
            else:
                wrf_vars['{}'.format(vname)] = get_wrf_vars(file_name, vname, hi)
                # wrf_vars['{}'.format(vname)] = xr.open_dataset(file_name)


        ## Calculation for dBZ:
        wrf_dbz_3hr = calculate_wrf_dbz(wrf_vars['P'],
                                        wrf_vars['TK'], 
                                        wrf_vars['QVAPOR'],
                                        wrf_vars['QRAIN'],
                                        wrf_vars['QSNOW'],
                                        wrf_vars['QGRAUP']
                                        ) # .to_dataset()
        
        # wrf_dbz_3hr = wrf_dbz_3hr.expand_dims({'TimeDim': 8})
        # print(wrf_dbz_3hr)
        
        if ( hi == 0 ):
            wrf_dbz = wrf_dbz_3hr
        else:
            wrf_dbz = xr.concat([wrf_dbz, wrf_dbz_3hr], dim='TimeDim')

    # print(wrf_dbz)
            
    ## Set output dataset:
    wrf_dataset_out = xr.open_dataset(file_name_dict['P'])    
      
    ## Add dBZ to output dataset:
    wrf_dataset_out['dBZ'] = (['Time', 'bottom_top', 'south_north', 'west_east'], wrf_dbz)
    #print(wrf_dataset_out)
    
    ## Drop P from the output dataset:
    wrf_dataset_out = wrf_dataset_out.drop_vars('P')
            
    ## Unstagger Z vertical grids:
    # wrf_var_Z_unstag = wrf.destagger(getvar(Dataset(file_name_dict['Z']), 'Z', timeidx=hi, meta=False), 0)

    ## Get AGL:
    # wrf_var_Z_AGL = wrf.g_geoht.get_height_agl(Dataset(file_name_dict['Z']), 'Z', meta=False)

    ## Add Z and dBZ into dataset of P:
    # wrf_dataset_P_Z_dBZ = xr.open_dataset(file_name_dict['P']).isel(Time = hi)
    # wrf_dataset_out = xr.open_dataset(file_name_dict['P'])
    # wrf_dataset_out['dBZ'] = (['bottom_top', 'south_north', 'west_east'], wrf_dbz)
    
    # wrf_dataset_P_Z_dBZ['TK'] = (['bottom_top', 'south_north', 'west_east'], wrf_vars['TK'])
    # wrf_dataset_P_Z_dBZ['Z'] = (['bottom_top', 'south_north', 'west_east'], wrf_var_Z_unstag)
        
    ## Calculate Z using the U.S. standard atmosphere & Hypsometric eqn.:
    # Z_standard = mpcalc.pressure_to_height_std((wrf_dataset_P_Z_dBZ['P'].values) * units.units.Pa)
    # wrf_dataset_P_Z_dBZ['Z_standard'] = (['bottom_top', 'south_north', 'west_east'], Z_standard)

    ## Set coordinates and dimensions:

    ## Set output file path and name:
    output_path_1 = '/glade/u/home/hungjui/2scratch/DATA_WRF_CONUS_1_dBZ_v1.0/' + wrf_sim_type
    # output_path_2 = '/20130913'
    output_path_2 = '/{}'.format(file_date_time.strftime('%Y'))
    output_file_name = set_output_name(file_date_time)
    wrf_dataset_out.to_netcdf(output_path_1 + output_path_2 + output_file_name)
        
    print('Finish this date.')

# %% [markdown]
# ### Main Program:

# %%
start = time.time()

## WRF Model Simulation Category:
wrf_sim_type = 'CTRL3D'

## Loop through a period:
target_date_range = pd.date_range(start='2013-1-1', end='2013-9-30', tz=pytz.utc)

for dayi in target_date_range:
    
    main_function(dayi)
    #main_calc = delayed(main_function)(dayi)
    
# main_calc.compute()
# main_calc.visualize()

end = time.time()
print("RUNTIME：%f SEC" % (end - start))
print("RUNTIME：%f MIN" % ((end - start)/60))
print("RUNTIME：%f HOUR" % ((end - start)/3600))
# Out:
# Processing: 20130101 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130102 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130103 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130104 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130105 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130106 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130107 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130108 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130109 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130110 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130111 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130112 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130113 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130114 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130115 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130116 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130117 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130118 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130119 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130120 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130121 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130122 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130123 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130124 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130125 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130126 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130127 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130128 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130129 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130130 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130131 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130201 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130202 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130203 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130204 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130205 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130206 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130207 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130208 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130209 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130210 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130211 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130212 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130213 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130214 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130215 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130216 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130217 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130218 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130219 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130220 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130221 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130222 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130223 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130224 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130225 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130226 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130227 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130228 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130301 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130302 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130303 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130304 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130305 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130306 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130307 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130308 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130309 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130310 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130311 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130312 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130313 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130314 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130315 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130316 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130317 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130318 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130319 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130320 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130321 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130322 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130323 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130324 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130325 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130326 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130327 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130328 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130329 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130330 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130331 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130401 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130402 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130403 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130404 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130405 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130406 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130407 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130408 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130409 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130410 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130411 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130412 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130413 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130414 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130415 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130416 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130417 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130418 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130419 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130420 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130421 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130422 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130423 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130424 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130425 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130426 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130427 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130428 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130429 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130430 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130501 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130502 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130503 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130504 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130505 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130506 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130507 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130508 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130509 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130510 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130511 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130512 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130513 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130514 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130515 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130516 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130517 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130518 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130519 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130520 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130521 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130522 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130523 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130524 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130525 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130526 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130527 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130528 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130529 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130530 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130531 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130601 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130602 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130603 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130604 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130605 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130606 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130607 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130608 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130609 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130610 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130611 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130612 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130613 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130614 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130615 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130616 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130617 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130618 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130619 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130620 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130621 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130622 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130623 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130624 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130625 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130626 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130627 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130628 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130629 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130630 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130701 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130702 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130703 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130704 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130705 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130706 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130707 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130708 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130709 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130710 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130711 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130712 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130713 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130714 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130715 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130716 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130717 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130718 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130719 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130720 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130721 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130722 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130723 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130724 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130725 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130726 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130727 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130728 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130729 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130730 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130731 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130801 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130802 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130803 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130804 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130805 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130806 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130807 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130808 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130809 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130810 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130811 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130812 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130813 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130814 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130815 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130816 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130817 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130818 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130819 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130820 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130821 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130822 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130823 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130824 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130825 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130826 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130827 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130828 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130829 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130830 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130831 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130901 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130902 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130903 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130904 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130905 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130906 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130907 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130908 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130909 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130910 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130911 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130912 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130913 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130914 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130915 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130916 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130917 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130918 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130919 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130920 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130921 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130922 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130923 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130924 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130925 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130926 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130927 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130928 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130929 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# Processing: 20130930 0|  1|  2|  3|  4|  5|  6|  7|  Finish this date.
# RUNTIME：54275.880949 SEC
# RUNTIME：904.598016 MIN
# RUNTIME：15.076634 HOUR

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
